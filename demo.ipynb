# %% [markdown]
# <a href="https://colab.research.google.com/github/HARSHA7317/python-code/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="harsha"
print(set(a))
print(a[::-1])
# Out:
# {'r', 'a', 'h', 's'}
# ahsrah
